# %% [markdown]
# Ceneo Scraper

# %% [markdown]
# 1. Import bibliotek

# %%
import requests 
from bs4 import BeautifulSoup

# %% [markdown]
# 2. strona produktu

# %%
produkt_id = "84514582"
url = f"https://www.ceneo.pl/{produkt_id}#tab=reviews"

# %% [markdown]
# 3. wysyłanie zadania dostepu do zasobu

# %%
response = requests.get(url)
response.status_code
# Out:
# 200

# %% [markdown]
# 4. Pobieranie opinii z kodu HTML strony

# %%
page = BeautifulSoup(response.text, "html.parser")
opinions = page.select("div.js_product-review")
opinion = page.select_one("div.js_product-review")
print(type(opinions))
print(type(opinion))
print(opinion)
# Out:
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.Tag'>
# <div class="user-post user-post__card js_product-review" data-entry-id="12535429">
# <header class="user-post__header">
# <div class="js_lazy user-post__avatar user-rank__avatar" data-bg="/Content/img/account/avatar/8.svg"></div>
# </header>
# <div class="user-post__body">
# <div class="user-post__content">
# <span class="user-post__author-name">
# g...6</span>
# <span class="user-post__score">
# <span class="screen-reader-text">Ocena:</span>
# <span class="score-container score-container--s js_score-container">
# <span class="score-marker score-marker--s" style="width: 60.00%;"></span>
# </span>
# <span class="user-post__score-count">3/5</span>
# <span class="user-post__published">
#         Wystawiono
#         <time datetime="2020-05-28 08:02:51">4 lata temu, </time>
# <time datetime="2020-05-04 22:29:44">po miesiącu</time> użytkowania            </span>
# </span>
# <div class="user-post__text">Instalacja łatwa. Oprogramowanie HP Smart bezproblemowe. Zwrot 100zl Cashback z Promocji po kilku dniach od zakupu. Skanuje. Drukuje. <br>
# Przez pierwsze 2-3 dni wszystko w porządku, wydruki czarne i kolorowe bardzo dobre. Po 3 dniu, zupełnie nagle, drukarka zaczyna drukować białe poziome kreski na wydrukach kolorowych. W czarnym bardzo dobrze. Wydruki w najlepszej jakości są bardzo dobre. Wydruki w jakości normalnej i roboczej są moim zdaniem wadliwe. Kupiłem 2 drukarki. Jedną udało mi się zwrócić w ramach 14 zwrotu. Druga niestety została. <br/>
# Producent HP raz uznał gwarancję. HP przysłałi nową głowicę kolorową, a jak problem nie został rozwiązany, całą nową drukarkę. Trzecia drukarka tak samo, drukuje białe kreski na wydrukach kolorowych. <br/>
# Zgłoszone ponownie do HP, tym razem w ocenie wsparcia HP, drukarki atramentowe tak drukują... Pozostawię to bez komentarza. Chciałem zgłosić w ramach rękojmi, niezgodność produktu z umową (reklamują outstanding printing quality), ale niestety kupiłem na firmę i rękojmia jest wyłączona. Nie wiem czy wadliwa seria drukarek, głowic, oprogramowania czy może ja coś źle robię przy 1-szym uruchamianiu, ale HP nie chce poznać i rozwiązać problemu. Dobre jest to, że po kilku dniach, pierwsze strony wydruków wychodzą ok, a kreski pojawiają się dopiero na 3-4 stronie. Może z czasem się to poprawi samo, jeśli problemem jest zapowietrzenie głowicy lub aktualizacja oprogramowania sprzętowego... <br/>
# Co ciekawe, HP nie wymaga odciągania tuszy strzykawką do wysyłki drukarki a sklep tak. Drugi raz bym nie kupił, chyba że sprawdzoną przetestowaną.</br></div>
# <div class="review-feature">
# <div class="review-feature__col">
# <div class="review-feature__title review-feature__title--positives">Zalety</div>
# <div class="review-feature__item">czyste napełnianie atramentem</div>
# <div class="review-feature__item">niski koszt wydruku</div>
# <div class="review-feature__item">szybkość wydruku</div>
# <div class="review-feature__item">wydajna</div>
# <div class="review-feature__item">wydajność</div>
# </div>
# <div class="review-feature__col">
# <div class="review-feature__title review-feature__title--negatives">Wady</div>
# <div class="review-feature__item">jakość wydruków</div>
# </div>
# </div>
# <div class="review-pictures js_product-review-carousel" data-hide-controls="true">
# <div class="review-pictures__item js_product-image-miniature_el active">
# <a class="js_gallery-trigger js_gallery-item js_gallery-anchor" data-index="0" data-type="img_user" href="//image.ceneostatic.pl/data/reviews/12535429/746b5949-c9f2-45b3-b33e-67419c2ee896_r-hp-smart-tank-515-aio-1tj09a.jpg">
# <img alt="HP Smart Tank 515 AiO (1TJ09A)" class="js_gallery-media js_review-product-thumb js_gallery-photo review-pictures__photo js_lazy" data-abuse-product-id="84514582" data-abuse-report-type="1" data-abuse-review-id="12535429" data-original="//image.ceneostatic.pl/data/reviews/12535429/746b5949-c9f2-45b3-b33e-67419c2ee896_t-hp-smart-tank-515-aio-1tj09a.jpg" src=""/>
# </a>
# </div>
# <div class="review-pictures__item js_product-image-miniature_el active">
# <a class="js_gallery-trigger js_gallery-item js_gallery-anchor" data-index="1" data-type="img_user" href="//image.ceneostatic.pl/data/reviews/12535429/8cd5b2a6-3757-4219-b64d-ad378b5da54b_r-hp-smart-tank-515-aio-1tj09a.jpg">
# <img alt="HP Smart Tank 515 AiO (1TJ09A)" class="js_gallery-media js_review-product-thumb js_gallery-photo review-pictures__photo js_lazy" data-abuse-product-id="84514582" data-abuse-report-type="1" data-abuse-review-id="12535429" data-original="//image.ceneostatic.pl/data/reviews/12535429/8cd5b2a6-3757-4219-b64d-ad378b5da54b_t-hp-smart-tank-515-aio-1tj09a.jpg" src=""/>
# </a>
# </div>
# </div>
# <div class="user-post__bottom">
# </div>
# </div>
# <div class="user-post__info">
# <div class="d-flex align-items-center justify-content-end">
# <div class="js_product-review-usefulness vote">
# <button class="vote-yes js_product-review-vote js_vote-yes" data-new-icon="vote-up" data-product-id="84514582" data-review-id="12535429" data-total-vote="19" data-url="SetOpinionVote" data-vote="1" data-voted="false"><span id="votes-yes-12535429">19</span></button>
# <button class="vote-no js_product-review-vote js_vote-no" data-new-icon="vote-down" data-product-id="84514582" data-review-id="12535429" data-total-vote="3" data-url="SetOpinionVote" data-vote="0" data-voted="false"><span id="votes-no-12535429">3</span></button>
# </div>
# <div class="dropdown-wrapper">
# <span class="dots-icon-vert" data-toggle="dropdown"></span>
# <ul class="dropdown-menu force-left">
# <li class="dropdown-menu__item" data-product-id="84514582" data-review-id="12535429">
# <div class="js_report-abuse report-abuse cursor-pointer" data-report-type="1" role="button">
# <span>
# Zgłoś    </span>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="review-pz" data-hint="Opinia została napisana przez Użytkownika, który kupił produkt.">
# <em>Transakcja pochodzi z Marketplace Ceneo (usługi Kup Teraz).</em>
# </div>
# </div>
# <div class="js_product-review-comments js_product-review-hook js_product-review-comments-list" id="product-review-comments-12535429">
# <a class="user-post js_product-review-comment-toggle" data-comments-count="5" data-product-review-id="84514582" data-review-id="12535429" href="#product-review-comment-12535429" role="button">
# </a>
# <div class="js_product-review-form-hook" id="product-review-comment-12535429"></div>
# <div class="user-post js_comment-from-user">
# <div class="user-post__header">
# <div class="js_lazy user-post__avatar user-rank__avatar" data-bg="/Content/img/account/avatar/10.svg">
# </div>
# </div>
# <div class="user-post__body js_product-review-hook" data-entry-id="434464">
# <div class="user-post__content">
# <span class="user-post__author-name">
#                                 aa
#                             </span>
# <span class="user-post__score">
# <span class="user-post__published">Wystawiono <time datetime="2021-02-07 14:16:31">4 lata temu</time></span>
# </span>
# <div class="user-post__text">
#                                 canon sa lepsze
#                             </div>
# <div class="user-post__bottom">
# <a class="link link--accent user-post__reply product-review-comment-reply-toggle js_open-login-popup-button" data-comment-id="434464" data-name="aa" data-product-review-id="84514582" data-review-id="12535429" href="#product-review-comment-reply-434464" rel="nofollow">Odpowiedz</a>
# </div>
# </div>
# <div class="user-post__info">
# <div class="dropdown-wrapper">
# <span class="dots-icon-vert" data-toggle="dropdown"></span>
# <ul class="dropdown-menu force-left">
# <li class="dropdown-menu__item" data-comment-id="434464" data-product-id="84514582">
# <div class="js_report-abuse report-abuse cursor-pointer" data-report-type="2" role="button">
# <span>
# Zgłoś    </span>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="js_product-review-form-hook" id="product-review-comment-reply-434464"></div>
# <div class="user-post">
# <div class="user-post__header">
# <div class="js_lazy user-post__avatar user-rank__avatar" data-bg="/Content/img/account/avatar/6.svg">
# </div>
# </div>
# <div class="user-post__body">
# <div class="user-post__content">
# <span class="user-post__author-name">
#                                                 zaz
#                                             </span>
# <span class="user-post__text">
# <span class="user-post__published">Wystawiono <time datetime="2021-10-20 17:59:46">3 lata temu</time></span>
# </span>
# <div class="user-post__text">
# canon mi padł po 3 latach.                                            </div>
# <div class="user-post__bottom">
# </div>
# </div>
# <div class="user-post__info">
# <div class="dropdown-wrapper">
# <span class="dots-icon-vert" data-toggle="dropdown"></span>
# <ul class="dropdown-menu force-left">
# <li class="dropdown-menu__item" data-comment-id="456334" data-product-id="84514582">
# <div class="js_report-abuse report-abuse cursor-pointer" data-report-type="2" role="button">
# <span>
# Zgłoś    </span>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="user-post js_comment-from-user">
# <div class="user-post__header">
# <div class="js_lazy user-post__avatar user-rank__avatar" data-bg="/Content/img/account/avatar/4.svg">
# </div>
# </div>
# <div class="user-post__body js_product-review-hook" data-entry-id="454345">
# <div class="user-post__content">
# <span class="user-post__author-name">
#                                 jerzy.76
#                             </span>
# <span class="user-post__score">
# <span class="user-post__published">Wystawiono <time datetime="2021-09-26 22:10:04">3 lata temu</time></span>
# </span>
# <div class="user-post__text">
#                                 może trzeba przeprowadzić wyrównanie głowicy?
#                             </div>
# <div class="user-post__bottom">
# <a class="link link--accent user-post__reply product-review-comment-reply-toggle js_open-login-popup-button" data-comment-id="454345" data-name="jerzy.76" data-product-review-id="84514582" data-review-id="12535429" href="#product-review-comment-reply-454345" rel="nofollow">Odpowiedz</a>
# </div>
# </div>
# <div class="user-post__info">
# <div class="dropdown-wrapper">
# <span class="dots-icon-vert" data-toggle="dropdown"></span>
# <ul class="dropdown-menu force-left">
# <li class="dropdown-menu__item" data-comment-id="454345" data-product-id="84514582">
# <div class="js_report-abuse report-abuse cursor-pointer" data-report-type="2" role="button">
# <span>
# Zgłoś    </span>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="js_product-review-form-hook" id="product-review-comment-reply-454345"></div>
# </div>
# </div>
# <div class="user-post js_comment-from-user">
# <div class="user-post__header">
# <div class="js_lazy user-post__avatar user-rank__avatar" data-bg="/Content/img/account/avatar/5.svg">
# </div>
# </div>
# <div class="user-post__body js_product-review-hook" data-entry-id="482914">
# <div class="user-post__content">
# <span class="user-post__author-name">
#                                 wislawisla*****
#                             </span>
# <span class="user-post__score">
# <span class="user-post__published">Wystawiono <time datetime="2022-09-14 12:17:12">2 lata temu</time></span>
# </span>
# <div class="user-post__text">
#                                 Nikt jeszcze nie dopisał że drukarka ma problemy z drukowaniem kopert. Żeby wydrukować kopertę możesz włożyć do podajnika tylko jedną kopertę, ale z kartką A4 pod spodem, bo inaczej drukarka nie wciągnie samej koperty!! Nie można też włożyć kilku kopert i drukować korespondencję seryjną! Dramat! Nie polecam a mam tą drukarkę od trzech lat w małym biurze. Podajnik papieru też jest niedopracowany.
#                             </div>
# <div class="user-post__bottom">
# <a class="link link--accent user-post__reply product-review-comment-reply-toggle js_open-login-popup-button" data-comment-id="482914" data-name="wislawisla*****" data-product-review-id="84514582" data-review-id="12535429" href="#product-review-comment-reply-482914" rel="nofollow">Odpowiedz</a>
# </div>
# </div>
# <div class="user-post__info">
# <div class="dropdown-wrapper">
# <span class="dots-icon-vert" data-toggle="dropdown"></span>
# <ul class="dropdown-menu force-left">
# <li class="dropdown-menu__item" data-comment-id="482914" data-product-id="84514582">
# <div class="js_report-abuse report-abuse cursor-pointer" data-report-type="2" role="button">
# <span>
# Zgłoś    </span>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="js_product-review-form-hook" id="product-review-comment-reply-482914"></div>
# </div>
# </div>
# <div class="user-post js_comment-from-user hidden">
# <div class="user-post__header">
# <div class="js_lazy user-post__avatar user-rank__avatar" data-bg="/Content/img/account/avatar/1.svg">
# </div>
# </div>
# <div class="user-post__body js_product-review-hook" data-entry-id="514587">
# <div class="user-post__content">
# <span class="user-post__author-name">
#                                 gdg
#                             </span>
# <span class="user-post__score">
# <span class="user-post__published">Wystawiono <time datetime="2023-09-10 19:07:17">8 miesięcy temu</time></span>
# </span>
# <div class="user-post__text">
#                                 gdfgdggdg
#                             </div>
# <div class="user-post__bottom">
# <a class="link link--accent user-post__reply product-review-comment-reply-toggle js_open-login-popup-button" data-comment-id="514587" data-name="gdg" data-product-review-id="84514582" data-review-id="12535429" href="#product-review-comment-reply-514587" rel="nofollow">Odpowiedz</a>
# </div>
# </div>
# <div class="user-post__info">
# <div class="dropdown-wrapper">
# <span class="dots-icon-vert" data-toggle="dropdown"></span>
# <ul class="dropdown-menu force-left">
# <li class="dropdown-menu__item" data-comment-id="514587" data-product-id="84514582">
# <div class="js_report-abuse report-abuse cursor-pointer" data-report-type="2" role="button">
# <span>
# Zgłoś    </span>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="js_product-review-form-hook" id="product-review-comment-reply-514587"></div>
# </div>
# </div>
# <div class="user-post js_comment-from-user hidden">
# <div class="user-post__header">
# <div class="js_lazy user-post__avatar user-rank__avatar" data-bg="/Content/img/account/avatar/9.svg">
# </div>
# </div>
# <div class="user-post__body js_product-review-hook" data-entry-id="523604">
# <div class="user-post__content">
# <span class="user-post__author-name">
#                                 yout
#                             </span>
# <span class="user-post__score">
# <span class="user-post__published">Wystawiono <time datetime="2024-02-07 19:13:53">3 miesiące temu</time></span>
# </span>
# <div class="user-post__text">
#                                 nie polecam problemy z głowicami..
#                             </div>
# <div class="user-post__bottom">
# <a class="link link--accent user-post__reply product-review-comment-reply-toggle js_open-login-popup-button" data-comment-id="523604" data-name="yout" data-product-review-id="84514582" data-review-id="12535429" href="#product-review-comment-reply-523604" rel="nofollow">Odpowiedz</a>
# </div>
# </div>
# <div class="user-post__info">
# <div class="dropdown-wrapper">
# <span class="dots-icon-vert" data-toggle="dropdown"></span>
# <ul class="dropdown-menu force-left">
# <li class="dropdown-menu__item" data-comment-id="523604" data-product-id="84514582">
# <div class="js_report-abuse report-abuse cursor-pointer" data-report-type="2" role="button">
# <span>
# Zgłoś    </span>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="js_product-review-form-hook" id="product-review-comment-reply-523604"></div>
# </div>
# </div>
# </div>
# <div class="user-post__bottom user-post__margin-bottom js_first-review-btn-container">
# <span class="user-post__comments link link--accent">
# <a class="link link--accent js_toggle-product-review-comments-first-top" href="#product-review-comments-12535429" rel="nofollow">
#                         Pokaż wszystkie komentarze (5)
#                     </a>
# </span>
# </div>
# </div>
# </div>

# %% [markdown]
# 5. Pobranie składowych pojedynczej opini

# %% [markdown]
# skadowa|zmienna|sekeltor|
# |------|-------|--------|
# |identyfikator opinii|opinion_id|["data-entry-id"]|
# |autora|author|span.user-post__author-name|
# |rekomendację|recomendation|span.user-post__author-recomendation > em|
# |liczbę gwiazdek|rating|span.user-post__score-count|
# |treść opinii|content|div.user-post__text|
# |listę zalet|pros|div.review-feature__title--positives ~ div.review-feature__item|
# |listę wad|cons|div.review-feature__title--negatives ~ div.review-feature__item|
# |data wystawienia opinii|opinion_date|span.user-post__published > time:nth-child(1)["datetime"]|
# |data zakupu produktu|purchase_date|opinion_date|span.user-post__published > time:nth-child(2)["datetime"]|
# |ile osób uznało opinię za przydatną|likes|button.vote-yes > span|
# |ile osób uznało opinię za nieprzydatną|dislikes|button.vote-no > span|

# %%
author = opinion.select_one("span.user-post__author-name").get_text().strip()
recomendation = opinion.select_one("span.user-post__author-recomendation > em").get_text().strip()
rating = opinion.select_one("span.user-post__score-count").get_text().strip()
content = opinion.select_one("div.user-post__text").get_text().strip()
pros = [p.get_text().strip() for p in opinion.select("div.review-feature__title--positives ~ div.review-feature__item")]
cons = [c.get_text().strip() for c in opinion.select("div.review-feature__title--negatives ~ div.review-feature__item")]
opinion_date = opinion.select_one("span.user-post__published > time:nth-child(1)")["datetime"].strip()
purchase_date = opinion.select_one("opinion_date|span.user-post__published > time:nth-child(2)")["datetime"].strip()
likes = opinion.select_one("button.vote-yes > span").get_text().strip()
dislikes = opinion.select_one("button.vote-no > span").get_text().strip()
opinion_id  = opinion.select_one("data-entry-id").strip()

pros_list = []
for p in pros:
    pros_list.append(p-get_text().strip())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 author = opinion.select_one("span.user-post__author-name").get_text().strip()
# ----> 2 recomendation = opinion.select_one("span.user-post__author-recomendation > em").get_text().strip()
#       3 rating = opinion.select_one("span.user-post__score-count").get_text().strip()
#       4 content = opinion.select_one("div.user-post__text").get_text().strip()
#
# AttributeError: 'NoneType' object has no attribute 'get_text'
